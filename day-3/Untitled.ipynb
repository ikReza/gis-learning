# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("default")

# %%
conduit = gpd.read_file("Shapefiles/Conduit_03.shp")

# %%
conduit.columns
# Out:
# Index(['SECT_SIZEI', 'SECT_SIZE', 'COND_TYPEI', 'COND_TYPE', 'D', 'FLOW',
#        'GIS_LABEL', 'ID', 'INV_STRT', 'INV_STP', 'LABEL', 'L', 'MATERIAL',
#        'COND_SHPID', 'COND_SHAPE', 'SLOP_M/KM', 'SRT_NODID', 'STRT_NODE',
#        'STOP_NOID', 'SOP_NODE', 'VEL_AVE', 'Dia_mm', 'Label_GIS', 'Fabs',
#        'Vabs', 'Layer', 'geometry'],
#       dtype='object')

# %%
conduit.shape
# Out:
# (271, 27)

# %%
conduit.plot(cmap="jet");

# %%
manhole = gpd.read_file("Shapefiles/Manhole_03.shp")

# %%
manhole.columns
# Out:
# Index(['DEPTH_OUT', 'SUMP_DPTH', 'ELEV_GND', 'ELEV_INV', 'ELEV_RIM',
#        'FLOWINTOT', 'FLOWOUTTOT', 'GIS_DIGIT', 'GIS_MAN', 'MAX_HGL', 'HGL_IN',
#        'HGL_OUT', 'ID', 'LABEL', 'OUTFALL', 'Label_GIS', 'geometry'],
#       dtype='object')

# %%
manhole.shape
# Out:
# (254, 17)

# %%
manhole.plot(cmap="jet");

# %%
fig, ax = plt.subplots(figsize=(20,10))
conduit.plot(ax=ax, edgecolor="black")
manhole.plot(ax=ax, color="tomato");
